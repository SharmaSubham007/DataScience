# %%
import pandas as pd
df = pd.read_csv("/Users/subhamsharma/study/NewFolder/Position_Salaries.csv")
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df.isnull().sum()
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x='Salary',data=df)
plt.show()

# %%
sns.histplot(x='Salary',data=df,hue='Position',multiple='fill')
plt.show()
